# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv("Information for Accommodation.csv",encoding='ascii')

# %%
df.head()
# Out:
#               Type                     Name  \
# 0  Boutique Hotels      THE THEVA RESIDENCY
# 1  Boutique Hotels           HIGHLAND VILLA
# 2  Boutique Hotels  ULAGALLA WALAWWA RESORT
# 3  Boutique Hotels         GALLE FORT HOTEL
# 4  Boutique Hotels    THE ELEPHANT CORRIDOR
#
#                                       Address  Rooms Grade      District  \
# 0         11/B5/10-1 06TH LANE, HANTANA,KANDY     10   NaN         Kandy
# 1  351, ABIMANGAMA ROAD, KUMBALGAMA, WELIGAMA     10   NaN        Matara
# 2                    THIRAPPANE, ANURADHAPURA     21   NaN  Anuradhapura
# 3          NO.28, CHURCH STREET, FORT , GALLE     14   NaN         Galle
# 4                   POTHANA,KIBISSA, SIGIRIYA     21   NaN        Matale
#
#                       AGA Division                   PS/MC/UC  Logitiute  \
# 0     Kandy Divisional Secretariat                      Kandy  80.635411
# 1  Weligama Divisional Secretariat  Weligama Pradeshiya Sabha  80.409972
# ...

# %%
df.groupby('Type')['Rooms'].sum()
# Out:
# Type
# Bangalows                        1462
# Boutique Hotels                   564
# Boutique Villas                   237
# Classified Hotels( 1-5 Star)    12828
# Guest Houses                     9685
# Heritage Bungalows                 19
# Heritage Homes                      8
# Home Stay Units                  1138
# Rented Apartments                 207
# Rented Homes                       19
# Tourist Hotels                   9962
# Name: Rooms, dtype: int64

# %%
df.groupby('Type')['Rooms'].mean()
# Out:
# Type
# Bangalows                        4.201149
# Boutique Hotels                 20.142857
# Boutique Villas                  6.583333
# Classified Hotels( 1-5 Star)    90.978723
# Guest Houses                    10.833333
# Heritage Bungalows               4.750000
# Heritage Homes                   4.000000
# Home Stay Units                  3.010582
# Rented Apartments                3.234375
# Rented Homes                     3.166667
# Tourist Hotels                  43.502183
# Name: Rooms, dtype: float64

# %%
df.groupby(['Type','District'])['Rooms'].sum().unstack(fill_value=0)
# Out:
# District                      Ampara  Anuradhapura  Badulla  Batticaloa  \
# Type
# Bangalows                          5            39       85          47
# Boutique Hotels                    0            21        0          40
# Boutique Villas                    0             0        0           0
# Classified Hotels( 1-5 Star)       0           505        0          51
# Guest Houses                     432           341      292         162
# Heritage Bungalows                 0             0        0           0
# Heritage Homes                     0             0        0           0
# Home Stay Units                   98            16      154          13
# Rented Apartments                  0             0        0           0
# Rented Homes                       0             0        0           0
# Tourist Hotels                    75            57      234         570
#
# District                      Colombo  Galle  Gampaha  Hambantota  Jaffna  \
# Type
# ...

# %%
df.head()
# Out:
#               Type                     Name  \
# 0  Boutique Hotels      THE THEVA RESIDENCY
# 1  Boutique Hotels           HIGHLAND VILLA
# 2  Boutique Hotels  ULAGALLA WALAWWA RESORT
# 3  Boutique Hotels         GALLE FORT HOTEL
# 4  Boutique Hotels    THE ELEPHANT CORRIDOR
#
#                                       Address  Rooms Grade      District  \
# 0         11/B5/10-1 06TH LANE, HANTANA,KANDY     10   NaN         Kandy
# 1  351, ABIMANGAMA ROAD, KUMBALGAMA, WELIGAMA     10   NaN        Matara
# 2                    THIRAPPANE, ANURADHAPURA     21   NaN  Anuradhapura
# 3          NO.28, CHURCH STREET, FORT , GALLE     14   NaN         Galle
# 4                   POTHANA,KIBISSA, SIGIRIYA     21   NaN        Matale
#
#                       AGA Division                   PS/MC/UC  Logitiute  \
# 0     Kandy Divisional Secretariat                      Kandy  80.635411
# 1  Weligama Divisional Secretariat  Weligama Pradeshiya Sabha  80.409972
# ...

# %%
df.groupby(['Type','District'])['Rooms'].sum().unstack(fill_value=0)
# Out:
# District                      Ampara  Anuradhapura  Badulla  Batticaloa  \
# Type
# Bangalows                          5            39       85          47
# Boutique Hotels                    0            21        0          40
# Boutique Villas                    0             0        0           0
# Classified Hotels( 1-5 Star)       0           505        0          51
# Guest Houses                     432           341      292         162
# Heritage Bungalows                 0             0        0           0
# Heritage Homes                     0             0        0           0
# Home Stay Units                   98            16      154          13
# Rented Apartments                  0             0        0           0
# Rented Homes                       0             0        0           0
# Tourist Hotels                    75            57      234         570
#
# District                      Colombo  Galle  Gampaha  Hambantota  Jaffna  \
# Type
# ...

# %%
df[df['District']=='Kandy'].groupby(['Type','AGA Division'])['Rooms'].sum().unstack(fill_value=0)
# Out:
# AGA Division                  Akurana Pradeshiya Sabha  Gagawata Koralya  \
# Type
# Bangalows                                            0                28
# Boutique Hotels                                      0                 0
# Boutique Villas                                      0                 0
# Classified Hotels( 1-5 Star)                         0                63
# Guest Houses                                         5                31
# Heritage Bungalows                                   0                 0
# Home Stay Units                                      0                44
# Rented Apartments                                    0                 2
# Rented Homes                                         0                 0
# Tourist Hotels                                       0                18
#
# AGA Division                  Gampola  Harispattuwa Pradeshiya Sabha  \
# Type
# Bangalows                           5                              3
# ...

# %%
df[df['District']=='Kandy'].groupby(['Type','AGA Division'])['Rooms'].sum().unstack(fill_value=0)
# Out:
# AGA Division                  Akurana Pradeshiya Sabha  Gagawata Koralya  \
# Type
# Bangalows                                            0                28
# Boutique Hotels                                      0                 0
# Boutique Villas                                      0                 0
# Classified Hotels( 1-5 Star)                         0                63
# Guest Houses                                         5                31
# Heritage Bungalows                                   0                 0
# Home Stay Units                                      0                44
# Rented Apartments                                    0                 2
# Rented Homes                                         0                 0
# Tourist Hotels                                       0                18
#
# AGA Division                  Gampola  Harispattuwa Pradeshiya Sabha  \
# Type
# Bangalows                           5                              3
# ...
